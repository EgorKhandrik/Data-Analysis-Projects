# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-данных-и-подготовка-их-к-анализу" data-toc-modified-id="Загрузка-данных-и-подготовка-их-к-анализу-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка данных и подготовка их к анализу</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии" data-toc-modified-id="Функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Функции для расчета и анализа LTV, ROI, удержания и конверсии</a></span><ul class="toc-item"><li><span><a href="#Создание-профилей" data-toc-modified-id="Создание-профилей-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Создание профилей</a></span></li><li><span><a href="#Функция-для-расчёта-Retention-Rate" data-toc-modified-id="Функция-для-расчёта-Retention-Rate-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Функция для расчёта Retention Rate</a></span></li><li><span><a href="#Функция-для-расчёта-Conversion-Rate" data-toc-modified-id="Функция-для-расчёта-Conversion-Rate-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Функция для расчёта Conversion Rate</a></span></li><li><span><a href="#Функция-для-расчёта-LTV-и-ROI" data-toc-modified-id="Функция-для-расчёта-LTV-и-ROI-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Функция для расчёта LTV и ROI</a></span></li><li><span><a href="#Функция-для-сглаживания-фрейма" data-toc-modified-id="Функция-для-сглаживания-фрейма-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Функция для сглаживания фрейма</a></span></li><li><span><a href="#Функция-для-визуализации-Retention-Rate" data-toc-modified-id="Функция-для-визуализации-Retention-Rate-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Функция для визуализации Retention Rate</a></span></li><li><span><a href="#Функция-для-визуализации-Conversion-Rate" data-toc-modified-id="Функция-для-визуализации-Conversion-Rate-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Функция для визуализации Conversion Rate</a></span></li><li><span><a href="#Функция-для-визуализации-LTV-и-ROI" data-toc-modified-id="Функция-для-визуализации-LTV-и-ROI-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Функция для визуализации LTV и ROI</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Выводы" data-toc-modified-id="Выводы-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Маркетинг" data-toc-modified-id="Маркетинг-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Маркетинг</a></span><ul class="toc-item"><li><span><a href="#Выводы" data-toc-modified-id="Выводы-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Оценка-окупаемости-рекламы-для-привлечения-пользователей" data-toc-modified-id="Оценка-окупаемости-рекламы-для-привлечения-пользователей-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Оценка окупаемости рекламы для привлечения пользователей</a></span><ul class="toc-item"><li><span><a href="#Анализ-общей-окупаемости-рекламы" data-toc-modified-id="Анализ-общей-окупаемости-рекламы-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Анализ общей окупаемости рекламы</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-рекламным-каналам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-рекламным-каналам-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по рекламным каналам</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-устройствам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-устройствам-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по устройствам</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-странам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-странам-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по странам</a></span></li><li><span><a href="#Промежуточные-выводы-по-окупаемости-рекламы" data-toc-modified-id="Промежуточные-выводы-по-окупаемости-рекламы-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Промежуточные выводы по окупаемости рекламы</a></span></li><li><span><a href="#Графики-конверсии-и-удержания-с-разбивкой-по-устройствам,-странам,-рекламным-каналам." data-toc-modified-id="Графики-конверсии-и-удержания-с-разбивкой-по-устройствам,-странам,-рекламным-каналам.-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Графики конверсии и удержания с разбивкой по устройствам, странам, рекламным каналам.</a></span></li></ul></li><li><span><a href="#Выводы-по-анализу" data-toc-modified-id="Выводы-по-анализу-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Выводы по анализу</a></span></li></ul></div>

# %% [markdown]
# # Анализ рекламных кампаний Procrastinate Pro+

# %% [markdown]
# Целью проекта является установить почему несмотря на вложения в рекламу и продвижение приложения Procrastinate Pro+, компания терпит убытки. Для достижения цели исследования выполним следующие задачи:
# * изучим общую информацию о предоставленных данных;
# * подготовим данные для анализа: выявим и устраним недостатки в данных, приведём данные к нужным типам;
# * определим период данных, по которому будет осуществляться анализ;
# * рассчитаем метрики LTV, CAC, ROI, Retention Rate и Convertion Rate в разрезе рекламных каналов, устройств, с которых юзеры заходят в приложение, и стран;
# * на основе метрик определим почему рекламные кампании были неэффективными и как это можно исправить.

# %% [markdown]
# ## Загрузка данных и подготовка их к анализу

# %% [markdown]
# Для начала ознакомимся с общей информацией о датасетах: количеством столбцов и строк, наименованием столбцов и типами данных в них, с конкретными данными датасета.
#
# Импортируем необходимые библиоткеи и модули:

# %%
import pandas as pd
pd.set_option('display.float_format', '{:,.2f}'.format)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(15, 8)})
import warnings
warnings.filterwarnings('ignore')
from datetime import date, timedelta
sns.set_style('whitegrid')
sns.set_palette("Paired", 24)

# %% [markdown]
# Сохраним анализируемые датафреймы в переменных *visits*, *orders*, *cost*:

# %%
visits = pd.read_csv('/datasets/visits_info_short.csv') # логи о посещении сайта
orders = pd.read_csv('/datasets/orders_info_short.csv') # информация о покупках
costs = pd.read_csv('/datasets/costs_info_short.csv') # информация о расходах на рекламу

# %% [markdown]
# Ознакомимся с общей информацией о таблице *visits* и данными в ней с помощью метода `info()`, а также выведем 5 первых строк датасета:

# %%
visits.info()
visits.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
# User Id          309901 non-null int64
# Region           309901 non-null object
# Device           309901 non-null object
# Channel          309901 non-null object
# Session Start    309901 non-null object
# Session End      309901 non-null object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# ...

# %% [markdown]
# В датафрейме *visits* отсутствуют пропуски в данных, однако столбцы названы некорректно (имеются пробелы и заглавные буквы), а данные о фремени представлены в формате *object*.

# %% [markdown]
# Также ознакомимся с таблицей *orders*:

# %%
orders.info()
orders.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
# User Id     40212 non-null int64
# Event Dt    40212 non-null object
# Revenue     40212 non-null float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99

# %% [markdown]
# Столбцы датафрейма *orders* также имеют стилистические ошибки, а формат данных в столбце *Event Dt* не соответствует ожидаемому.

# %% [markdown]
# Оценим общие сведения и по таблице *costs*:

# %%
costs.info()
costs.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
# dt         1800 non-null object
# Channel    1800 non-null object
# costs      1800 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom 113.30
# 1  2019-05-02  FaceBoom  78.10
# 2  2019-05-03  FaceBoom  85.80
# 3  2019-05-04  FaceBoom 136.40
# 4  2019-05-05  FaceBoom 122.10

# %% [markdown]
# Как и в двух предыдущих датафреймах в таблице *costs* требуют изменений наименования столбцов и формат данных в столбце *dt*.

# %% [markdown]
# Приведем наименования строк в датасетах в строчный формат, а также переименуем столбцы *user id*, *session start*, *session end* в таблице *visits* и столбцы *user id*, *event dt* в датафрейме *orders* - добавим вместо пробелов в наименованиях столбцов символ нижнего подчеркивания:

# %%
visits.columns = visits.columns.str.lower()
visits.columns = visits.columns.str.replace(' ', '_')

orders.columns = orders.columns.str.lower()
orders.columns = orders.columns.str.replace(' ', '_')

costs.columns = costs.columns.str.lower()

display(visits.columns)
display(orders.columns)
display(costs.columns)
# Out:
# Index(['user_id', 'region', 'device', 'channel', 'session_start',
#        'session_end'],
#       dtype='object')
# Index(['user_id', 'event_dt', 'revenue'], dtype='object')
# Index(['dt', 'channel', 'costs'], dtype='object')

# %% [markdown]
# Таким образом, наименования столбцов приведены в удобный для дальнейшей работы формат.

# %% [markdown]
# Также во всех датасетах сведения о дате и времени имеют формат *object*, поэтому необходимо привести данные в соответствующих столбцах в подходящий формат с помощью метода *to_datetime()*:

# %%
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])
orders['event_dt'] = pd.to_datetime(orders['event_dt'])
costs['dt'] = pd.to_datetime(costs['dt']).dt.date

# %%
visits['session_end'].max()
# Out:
# Timestamp('2019-11-01 01:38:46')

# %% [markdown]
# Проверим имеются ли в датафреймах дубликаты:

# %%
print(f'Количество дубликатов в датасете visits: {visits.duplicated().sum()}')
print(f'Количество дубликатов в датасете orders: {orders.duplicated().sum()}')
print(f'Количество дубликатов в датасете costs: {costs.duplicated().sum()}')
# Out:
# Количество дубликатов в датасете visits: 0
# Количество дубликатов в датасете orders: 0
# Количество дубликатов в датасете costs: 0

# %% [markdown]
# ### Вывод

# %% [markdown]
# Наименования столбцов датафреймов были приведены в корректный формат, а также изменён формат данных в столбцах со временем. Данные подготовлены для дальнейшей работы.

# %% [markdown]
# ## Функции для расчета и анализа LTV, ROI, удержания и конверсии

# %% [markdown]
# Создадим функции для расчёта и визуализации LTV, ROI, удержания и конверсии:

# %% [markdown]
# ### Создание профилей

# %%
def get_profiles(sessions, orders, ad_costs):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# ### Функция для расчёта Retention Rate

# %%
# функция для расчёта удержания

def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для расчёта Conversion Rate

# %%
# функция для расчёта конверсии

def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для расчёта LTV и ROI

# %%
# функция для расчёта LTV и ROI

def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# ### Функция для сглаживания фрейма

# %%
# функция для сглаживания фрейма

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# ### Функция для визуализации Retention Rate

# %%
# функция для визуализации удержания

def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция для визуализации Conversion Rate

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция для визуализации LTV и ROI

# %%
# функция для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Вывод

# %% [markdown]
# Используем указанные функции при дальнейшем анализе.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# Выясним:
#
# - Из каких стран приходят посетители? Какие страны дают больше всего платящих пользователей?
# - Какими устройствами они пользуются? С каких устройств чаще всего заходят платящие пользователи?
# - По каким рекламным каналам шло привлечение пользователей? Какие каналы приносят больше всего платящих пользователей?

# %% [markdown]
# Для начала создадим проили пользователей, вызвав функцию *get_profiles*:

# %%
profiles = get_profiles(visits, orders, costs)
profiles.head()
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True              1.09
# 1  2019-07-09 2019-07-01  False              1.11
# 2  2019-10-01 2019-10-01  False              0.00
# 3  2019-08-22 2019-08-01  False              0.99
# 4  2019-10-02 2019-10-01  False              0.23

# %% [markdown]
# Изучим максимальную и минимальную даты, в которые юзеры впервые пользовались приложением:

# %%
print(f'Минимальная дата: {profiles["first_ts"].min()}')
print(f'Максимальная дата: {profiles["first_ts"].max()}')
# Out:
# Минимальная дата: 2019-05-01 00:00:41
# Максимальная дата: 2019-10-27 23:59:04

# %% [markdown]
# Таким образом, имеется информация о пользователях, привлечённых в период с 01 мая 2019 г. по 27 ноября 2019 г.

# %% [markdown]
# Исследуем из каких стран приходит больше всего платящих пользователей. Начнём с того, что выясним сведения о юзерах с каких стран имеютя данные:

# %%
profiles['region'].unique()
# Out:
# array(['United States', 'Germany', 'France', 'UK'], dtype=object)

# %% [markdown]
# Приложением в иследуемый период пользовались юзеры четырёх стран: США, Франции, Германии и Великобритании. Создадим таблицу, которая будет содеражть сведения об общем количестве юзеров, о количестве платяющих пользователей и проценте платящих юзеров от общего количества юзеров в разбивке по странам, сохраним в переменной *payers*:

# %%
payers = (
    profiles
    .groupby('region') # сгруппируем данные по столбцу region
    .agg({'user_id': 'nunique', 'payer': ['sum', 'mean']}) # посчитаем общее количество уникальных пользователей, приходящихся 
                                                           # на страну, количестве платяющих юзеров и проценте платящих юзеров
)

payers.columns = ['total_users', 'total_payers', '% of payers'] # переимунеуем столбцы

cm = 'Greens' # зададим цвет для окрашивания ячеек
(
    payers
    .sort_values(by='total_users', ascending=False) # отсортируем данные по убыванию общего кол-ва юзеров
    .style.format({'% of payers':'{:.2%}'}).background_gradient(cmap=cm) # окрасим ячейки в каждой колонке по размеру показателя
)
# Out:
# <style  type="text/css" >
#     #T_891201de_877d_11ec_b5a3_02420a39c260row0_col0 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_891201de_877d_11ec_b5a3_02420a39c260row0_col1 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_891201de_877d_11ec_b5a3_02420a39c260row0_col2 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_891201de_877d_11ec_b5a3_02420a39c260row1_col0 {
#             background-color:  #f3faf0;
#             color:  #000000;
#         }    #T_891201de_877d_11ec_b5a3_02420a39c260row1_col1 {
#             background-color:  #f5fbf3;
#             color:  #000000;
#         }    #T_891201de_877d_11ec_b5a3_02420a39c260row1_col2 {
#             background-color:  #f5fbf2;
#             color:  #000000;
#         }    #T_891201de_877d_11ec_b5a3_02420a39c260row2_col0 {
#             background-color:  #f3faf0;
#             color:  #000000;
# ...

# %% [markdown]
# Таким образом, основной трафик пользователей приходится на США. Пользователи из Соединённых Штатов также чаще чем пользователи из других стран конвертрируются в платящих. Юзеры из Великобритании, Франции и Германии являются сопоставимыми как по количеству в исследуемом периоде, так и по проценту платящих.

# %% [markdown]
# Узнаем с каких устройств чаще всего пользователи заходят в приложение и совершают покупки:

# %%
devices = (
    profiles
    .groupby('device') # сгруппируем данные по столбцу device
    .agg({'user_id': 'nunique', 'payer': ['sum', 'mean']}) # посчитаем общее количество уникальных пользователей, приходящихся 
                                                           # на девайс, количестве платяющих юзеров и проценте платящих юзеров
)

devices.columns = ['total_users', 'total_payers', '% of payers'] # переимунеуем столбцы

(
    devices
    .sort_values(by='total_users', ascending=False) # отсортируем данные по убыванию общего кол-ва юзеров
    .style.format({'% of payers':'{:.2%}'}).background_gradient(cmap=cm) # окрасим ячейки в каждой колонке по размеру показателя
)
# Out:
# <style  type="text/css" >
#     #T_8b0314ba_877d_11ec_b5a3_02420a39c260row0_col0 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_8b0314ba_877d_11ec_b5a3_02420a39c260row0_col1 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_8b0314ba_877d_11ec_b5a3_02420a39c260row0_col2 {
#             background-color:  #005e26;
#             color:  #f1f1f1;
#         }    #T_8b0314ba_877d_11ec_b5a3_02420a39c260row1_col0 {
#             background-color:  #d1edcb;
#             color:  #000000;
#         }    #T_8b0314ba_877d_11ec_b5a3_02420a39c260row1_col1 {
#             background-color:  #bbe4b4;
#             color:  #000000;
#         }    #T_8b0314ba_877d_11ec_b5a3_02420a39c260row1_col2 {
#             background-color:  #3ea75a;
#             color:  #000000;
#         }    #T_8b0314ba_877d_11ec_b5a3_02420a39c260row2_col0 {
#             background-color:  #f3faf0;
#             color:  #000000;
# ...

# %% [markdown]
# * Большинство пользователей используют приложение на устройствах iPhone, процент платящих юзеров с устройств iPhone близок к максимальному значению и составляет более 6%. Пользователей с Android было меньше почти на 20 тыс., процент сконвертировавшихся юзеров также меньше, чем у iPhone.
# * Максимальная доля платящих пользователей среди пользователей Мас. При этом по сравнению с PC доля платящих юзеров Mac на 1,3% больше, учитывая, что общее количество юзеров в этом периоде у обоих десктопных устройств примерно одинаковое.

# %% [markdown]
# Оценим какие каналы привлечения обеспечили максимальный трафик и платящих пользователей:

# %%
channels = (
    profiles
    .groupby('channel') # сгруппируем данные по столбцу channel
    .agg({'user_id': 'nunique', 'payer': ['sum', 'mean']}) # посчитаем общее количество уникальных пользователей, приходящихся 
                                                           # на канал, количестве платяющих юзеров и проценте платящих юзеров
)
channels.reset_index()
channels.columns = ['total_users', 'total_payers', '% of payers'] # переимунеуем столбцы

display(
    channels
    .sort_values(by='total_users', ascending=False) # отсортируем данные по убыванию общего кол-ва юзеров
    .style.format({'% of payers':'{:.2%}'}).background_gradient(cmap=cm) # окрасим ячейки в каждой колонке по размеру показателя
)

(
    channels
    .plot(kind='pie', y='total_payers', autopct='%.0f%%', # построим piechart с распределением юзеров по каналам привлечения
          title='Распределение покупателей по каналам привлечения')
    .set_ylabel('')
)
plt.legend(bbox_to_anchor=(1.3,0.5), loc="center left", borderaxespad=0);
# Out:
# <style  type="text/css" >
#     #T_8c82667e_877d_11ec_b5a3_02420a39c260row0_col0 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_8c82667e_877d_11ec_b5a3_02420a39c260row0_col1 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_8c82667e_877d_11ec_b5a3_02420a39c260row0_col2 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_8c82667e_877d_11ec_b5a3_02420a39c260row1_col0 {
#             background-color:  #3ca559;
#             color:  #000000;
#         }    #T_8c82667e_877d_11ec_b5a3_02420a39c260row1_col1 {
#             background-color:  #72c375;
#             color:  #000000;
#         }    #T_8c82667e_877d_11ec_b5a3_02420a39c260row1_col2 {
#             background-color:  #29914a;
#             color:  #000000;
#         }    #T_8c82667e_877d_11ec_b5a3_02420a39c260row2_col0 {
#             background-color:  #caeac3;
#             color:  #000000;
# ...

# %% [markdown]
# * Больше всего за исследуемый период было органических юзеров, но процент платящих ожидаемо самый низкий в сравнении с иными каналами привлечения.
#
# * Рекламный источник, который привлёк большинство новых пользователей - FaceBoom - также имеет и максимальный процент конвертации пользователей в платящих.
#
# * Рекламные источники OppleCreativeMedia, LeapBob и WahooNetBanner хоть и привлекли порядка 8,5 тыс. новых пользователей, но эти пользователи нечасто становились плательщиками. Особенно это касается OppleCreativeMedia, LeapBob - процент сконвертировавшихся пользователей по этим каналам немногим больше чем у органических пользователей.
#
# * Особое внимание на себя обращают результаты по рекламным каналам AdNonSense и lambdaMediaAds, из которых пришло меньше всего пользователей, но зато такие пользователи охотно становились плательщиками - процент платещих юзеров по этим каналам устапает только лидеру по итогу исследуемого периода FaceBoom.
#
# * Топ-3 каналов привлечения по количеству платящих пользователей совпадает с лидерами по общему количеству привлечённы пользователей в периоде: FaceBoom, TipTop и органические юзеры.

# %% [markdown]
# ### Выводы

# %% [markdown]
# Чаще всего новые пользователи были из США, пользовались приложением с iPhone и были органическими либо привлечены через рекламные каналы FaceBoom или TipTop. Эти же юзеры чаще других совершали покупки в приложении.

# %% [markdown]
# ## Маркетинг
#
# Выясним:
# - Сколько денег потратили? Всего / на каждый источник / по времени.
# - Сколько в среднем стоило привлечение одного покупателя из каждого источника?

# %% [markdown]
# Узнаем сколько всего было потрачено на маркетинг:

# %%
print(f'Расходы на маркетинг составили: {costs["costs"].sum().round(1)}')
# Out:
# Расходы на маркетинг составили: 105497.3

# %% [markdown]
# Также посмотрим на распределение расходов в разбивке по рекламным каналам: всего за период и в каждом месяце

# %%
costs['dt'] = pd.to_datetime(costs['dt']).dt.date
costs['month'] = costs['dt'].astype('datetime64[M]')

plt.figure(figsize=(20, 25))
costs_by_channel = costs.groupby('channel').agg({'costs':'sum'}).sort_values(by='costs', ascending=False).reset_index()
sns.barplot(x='channel', y='costs', data=costs_by_channel, 
            color='lightblue', ax=plt.subplot(3,1,1)) # график с общими расходами по каналам
plt.title('Общие расходы на привлечение по каналам', fontsize=20)
plt.xlabel('Канал привлечения', fontsize=15)
plt.ylabel('Размер расходов', fontsize=15)
plt.axhline(y=costs_by_channel["costs"].median(), # зададим на графике линию, отображающую медианное значение расходов
            color='red',
           linestyle='--',
           label = 'Медианный уровень затрат')
plt.legend(bbox_to_anchor = (1.0, 1), loc = 'best');

plt.figure(figsize=(25, 25))
costs_by_channel.set_index('channel').plot(kind='pie', y='costs', 
                                           autopct='%.0f%%', ax=plt.subplot(3,1,2)) # пострим piechart с расходами по каналам
                                                                                                           
plt.title('Распределение расходов по каналам привлечения', fontsize=20)
plt.legend(bbox_to_anchor = (1.0, 1), loc = 'best');

plt.figure(figsize=(20, 25))
(
    costs
    .pivot_table(index='month', columns='channel', values='costs', aggfunc='sum') # создадим сводную таблицу с помесячными 
                                                                                  # расходами по каналам
    .plot(ax=plt.subplot(3,1,3)) # построим график с помесячными расходами по каналам
)
plt.title('Расходы в каждом месяце на привлечение по каналам', fontsize=20)
plt.xlabel('Месяц', fontsize=15)
plt.ylabel('Размер расходов', fontsize=15);

# %% [markdown]
# По распределеню расходов на привлечение по рекламным каналам можно отметить следующее:
# * Как видим больше половины от всех расходов на привлечение пришлось на канал TipTop, который, как было установлено выше, в исследуемый период привлёк меньше пользователей, чем канал FaceBoom. При этом затраты на рекламу в FaceBoom были на 20 тыс. меньше.
#
# * Расходы на привлечение через TipTop росли в течение всего анализируемого периода: если в мае расходы на данный канал составляли порядка 30 тыс., то к октябрю расходы в месяц были более 120 тыс. Месячные расходы на продвижение в канале FaceBoom также росли, но не так быстро как в канале TipTop, - за весь период расходы выросли с ~35 тыс. до ~60 тыс. в месяц. Следовательно, если в начале расходы на TipTop и FaceBoom были сопостовимыми, то к концу исследуемого периода расходы на продвижение в TipTop существенно опережали расходы на FaceBoom, хотя через последний канал удалось значительно больше привлечь как и общего количества пользователей, так и платящих пользователей.
#
# * Третьим каналом по количеству расходов на продвижение является WahooNetBanner, месячные расходы на который оставились стабильными.
#
# * Обращает на себя внимание общие затраты по каналу AdNonSense - через данный канал было привлечено минимальное количество пользователей в периоде, но AdNonSense позволил привлечь 5% платящих пользователей в периоде, что находится на уровне WahooNetBanner.

# %% [markdown]
# Рассчитаем среднюю стоимость привлечения пользователя (**CAC**) по всему проекту:

# %%
profiles = profiles.query('channel != "organic"') # исключаем органических пользователей
print(f'Средний CAC по проекту: {profiles["acquisition_cost"].mean().round(3)}')
# Out:
# Средний CAC по проекту: 1.127

# %% [markdown]
# Посмотрим на динамику САС в периоде в разрезе по каналам привлечения:

# %%
plt.figure(figsize=(20, 25))
(
    profiles
    .pivot_table(index='month', columns='channel', values='acquisition_cost', aggfunc='mean') # посчитаем средний САС по каналам
    .plot() # построим график среднего САС по каналам
)
plt.axhline(y=profiles["acquisition_cost"].mean(), # зададим на графике линию со средним САС по проекту
            color='red',
           linestyle=':',
           label = 'Средний САС по проекту')
plt.axhline(y=profiles["acquisition_cost"].median(), # зададим на графике линию с медианным САС по проекту
            color='blue',
           linestyle=':',
           label = 'Медианный САС по проекту')
plt.ylabel('CAC, $', fontsize=15)
plt.xlabel('Дата привлечения', fontsize=15)
plt.title('Динамика САС по каналам привлечения', fontsize=20)
plt.legend(bbox_to_anchor = (1.0, 1), loc = 'best');

# %% [markdown]
# Общие выводы по САС в исследуемом периоде:
# * САС в исследуемом периоде увеличивался только по каналу TipTop, на который и было потрачено больше всего. Динамика на снижение САС зафиксирована только по каналу RocketSuperAds. По остальным каналам показатель стоимости привлечения одного пользователя оставался стабильным на протяжении всего анализируемого периода.
#
# * CAC по каналу TipTop находился выше среднего и медианного по проекту. САС по каналу FaceBoom примерно соответствует среднему и медианному по всему проекту. По остальным каналам САС ниже среднего и медианного.

# %% [markdown]
# ### Выводы

# %% [markdown]
# Затраты на рекламу в TipTop были максимальными в исследуемом периоде, но принесли меньше пользователей, в т.ч. платящих, чем реклама в FaceBoom. Кроме того, по TipTop увеличивалась стоимость привлечения одного пользователя гораздо быстрее, чем по FaceBoom.

# %% [markdown]
# ## Оценка окупаемости рекламы для привлечения пользователей

# %% [markdown]
# ### Анализ общей окупаемости рекламы

# %% [markdown]
# Рассчитаем общую окупаемость рекламы с помощью метрик LTV и ROI:

# %%
observation_date = pd.datetime(2019, 11, 1).date()  # момент анализа
horizon_days = 14  # горизонт анализа 

profiles = profiles.query('channel != "organic"') 

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days
)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# По метрикам LTV и ROI можно сделать следующие выводы:
# - LTV достаточно стабилен и не сильно изменялся в периоде;
# - реклама не окупается, т.к. на 14 день ROI составляет всего 80%. При этом по динмике ROI видно, что в начале периода инвестиции в рекламу окупались, а после июня ROI только снижался. Стоимость привлечения одного пользователя (САС) увеличивалась на протяжении всего периода, т.е. затраты на привлечение пользователей росли. Как было установлено ранее, повышение САС в периоде было только по одному каналу - TipTop.
#
# *Предположим, что реклама не окупается из-за больших вложений в рекламу на канале TipTop, через который не было привлечено достаточное количество платящих пользователей - и по общему количеству привлечённых пользователей и по проценту платящих пользователей TipTop не является лидером, несмотря на самые большие вложения в него.*

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по рекламным каналам

# %%
dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=30
)

# %% [markdown]
# При оценке LTV, CAC и ROI в разрезе рекламных каналов обращает на себя внимание следующее:
# * Реклама в FaceBoom и TipTop - лидеры по количеству привлечённых пользователей и по размеру затрат на рекламу - не окупается на 14 день. Также ROI менее 100% по каналу AdNonSense. Стоит отметить, что затраты на AdNonSense и на WahooNetBanner были сопоставимыми, данные каналы повзволили привлечь по 5% от платящих пользователей, но затраты на WahooNetBanner окупились и принесли прибыль.
# * По всем остальным каналам ROI является гораздо больше 100%, а по некоторым и больше 200% на 14 день.
# * LTV на 14 день для юзеров, привлечённых через TipTop стабильно один из самых высоких. У пользователей, пришедших в приложение через FaceBoom, уровень LTV находится на среднем уровне по сравнению с иными каналами, но уступает каналу RocketSuperAds.

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по устройствам

# %%
dimensions = ['device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# LTV юзеров iPhone, Mac и Android на 14 день примерно одинаков.
# Как видим, на 14 день окупается только привлечение пользователей на РС, ROI пользователей, использующих остальные устройства менее 100%. При этом в помесячной разбивке к концу периода привлечение пользователей ни по одному из устройств не окупается, что возможно связать с увеличением расходов на рекламу и САС к концу периода, а также с возможной проблемой с приложением, которая имеется на всех платформах.

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по странам

# %%
dimensions = ['region']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# * САС рос только по привлечению пользователей из США, являющимися основными юзерами приложения, инвестиции в привлечение которых не окупились. По юзерам из друих стран ситуация лучше: САС оставался стабильным, вложения в их привлечение окупились и принесли прибыль. динамика LTV на 14 день оставалась стабильной.
# * Стоит отметить, что LTV юзеров из Германии к концу исследуемого периода приблизился к уровню пользователей из США.
#
# *Возможно такая ситуация сложилась из-за того, что пользователи из США привлекаются в основном из каналов, вложения в рекламу которых не окупается. Проверим по каким каналам привлекаются пользователи из разных стран:*

# %%
profiles.pivot_table(index='channel', columns='region', aggfunc='sum', values='acquisition_cost')
# Out:
# region               France  Germany       UK  United States
# channel
# AdNonSense         1,376.32 1,229.28 1,305.65            nan
# FaceBoom                nan      nan      nan      32,445.60
# LeapBob              628.05   529.95   639.61            nan
# MediaTornado            nan      nan      nan         954.48
# OppleCreativeMedia   747.34   640.73   763.18            nan
# RocketSuperAds          nan      nan      nan       1,833.00
# TipTop                  nan      nan      nan      54,751.30
# WahooNetBanner     1,789.14 1,552.97 1,808.89            nan
# YRabbit                 nan      nan      nan         944.22
# lambdaMediaAds       535.14   471.29   551.17            nan

# %% [markdown]
# Действительно, юзеры из Соединённых Штатов привлекаются в основном из каналов FaceBoom и TipTop, в то время как юзеры из Европы по этим каналам не привлекаются вовсе. Поэтому метрики ROI и САС по юзерам из США польностью повторяют тенденцию данных по FaceBoom и TipTop.

# %% [markdown]
# ### Промежуточные выводы по окупаемости рекламы

# %% [markdown]
# По результатам анализа LTV, ROI и САС можно прийти к следующим промежуточным выводам:
# - в общем инвестиции в рекламу не окупаются, САС рос на протяжении всего периода, но LTV при этом оставался стабильным;
# - на кампании в TipTop было потрачено более 50% бюджета, но платящих пользователей, пришедших через этот канал всего 21%;
# - основная причина в низких показателях ROI - вложения в привлечение трафика через FaceBoom и TipTop (основные каналы, через который привлекаются юзеры из США), не окупаются. Стоимость привлечения одного пользователя через TipTop весь анализируемый период росла;
# - окупаемость зафиксирована только по юзерам с PC, хотя к концу исследуемого периода и юзеры PC перестали окупаться. Возможно, имеет место баг приложения на всех платформах.

# %% [markdown]
# ### Графики конверсии и удержания с разбивкой по устройствам, странам, рекламным каналам.

# %%
dimensions = ['device']

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Максимальную конвертацию демонстрируют пользователи iPhone и Mac. Конвертация пользователей РС гораздо меньше, чем юзеров с других устройств.

# %%
dimensions = ['device']

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days, window=20)

# %% [markdown]
# Юзеры iPhone, Mac и Android удерживаются хуже, чем пользователи PC. Стабильно в разбивке по месяцам ниже всех уровень удержания на 14 день у тех, кто пользуется приложением с iPhonе (большая часть аудитории приложения). К 14 дню уровень удржания по всем устройствам составляет менее 10%. В условиях растущей стоимости привлечения клиентов такой уровень удержания стоит признать низким.

# %% [markdown]
# Посмотрим как распределена конверсия пользователей в разбивке по странам:

# %%
dimensions = ['region']

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Лучше всего конвертируются пользователи из США, составляющие основную часть плательщиков в приложении.

# %% [markdown]
# Оценим также уровень удержания пользователей из разных стран:

# %%
dimensions = ['region']

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days, window=5)

# %% [markdown]
# Однако юзеры из США хуже всего удерживаются - к 14 дню менее 10% юзеров пользуются приложением. С пользователями их других стран уровень удержания немного выше, чем у юзеров из США, но на 14 день он не превышает 20%. Возможно, такой низкий уровень удержания пользователей из США связан с каналами, на которых для рынка США проводятся рекламные кампании приложения.

# %% [markdown]
# Оценим конвертацию юзеров в разрезе каналов привлечения трафика:

# %%
dimensions = ['channel']

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days, window=30)

# %% [markdown]
# Канал, в который были вложено максимум средств на продвижение, - TipTop - уступает по уровню конвертации пользователей каналам FaceBoom, AdNonSense и LambdaMediaAds. FaceBoom является лидером по уровню сконвертировавшихся пользователей.

# %% [markdown]
# Построим графики удержания юзеров в разрезе каналов привлечения:

# %%
dimensions = ['channel']

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days, window=5)

# %% [markdown]
# * Как видим, у юзеров, пришедших с каналов FaceBoom и AdNonSense крайне низкий уровень удержания. Уже к 4 дню пользователей, пришедшие с этих каналов, остаётся менее 10%, а к 14 дню - меньше 5%. Поэтому становится ясно почему такой низкий показатель удержания юзеров из США - основным каналом привлечения пользователей из этой страны является FaceBoom.
# * Остальные каналы (за исключением YRabbit и MediaTornado) показывают примерно одинаковый результат в 20% удержанных платящих пользователей к 14 дню.
# * Обратим внимание, что уровень удержания пользователей, пришедших по рекламе с RocketSuperAds, один из самых высоких (порядка 25% к 14 дню).

# %% [markdown]
# ## Выводы по анализу

# %% [markdown]
# По результатам анализа можно выделить следуюшие причины неэффективности привлечения пользователей:
# - рекламные кампании в основном проводятся на каналах с высоким САС, который продолжал расти (по каналу TipTop). Вложения в рекламу в этих каналах (TipTop, FaceBoom) приносили убыток, а пользователи неохотно оставались (уровень удержания по FaceBoom критически мал);
#
# - неудачные с точки зрения ROI, CAC и удержания рекламные кампании в TipTop и FaceBoom стали причиной, что основная аудитория приложения - пользователей из США - убыточни с точки зрения их привлечения и неохотно пользуются приложением к 14 дню;
#
# - уровень конверсии юзеров из Европы значительно ниже, чем у юзеров из США и требует повышения;
#
# - при оценке удержания юзеров в разбивке по устройствам установлено, что удержание к 14 дню составляет менее 10%, а самый низкий уровень удержания у пользователей приложения на iPhonе.

# %% [markdown]
# Рекомендации для повышения эффективности привлечения пользователей:
# - пересмотреть распределение бюджета по рекламным каналам для привлечения пользователей из США. Основными каналами в настоящее время для привлечения пользователей из США являются FaceBoom и TipTop. Однако вложения в рекламу в этих каналах не окупается, а уровень САС растёт. Кроме того, удержание пользователей из канала FaceBoom находится на критическом уровне менее 5% к 14 дню, что сказывается на общем уровне удержания юзеров из США. Из анализируемых каналов привлечения юзеров из США показатели окупаемости, конверсии и удержания лучше всего у RocketSuperAds, САС по которому снижался к концу анализируемого периода;
#
# - по каналам привлечения пользователей из Европы стоит обратить внимание на канал lambdaMediaAds - юзеры, пришедшие с кампаний  в этом канале показывали лучший LTV, ROI и Retention, чем AdNonSense и WahooNetBanner (в эти каналы было вложено больше всего средств для продвижения среди европейской аудитории). При этом AdNonSense показывает минимальное удержание пользователей;
#
# - стоит оценить возможные улучшения в версиях приложения на всех платформах для повышения удержания.
